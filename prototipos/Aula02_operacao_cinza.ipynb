# %%
import sys  
import os
sys.path.insert(0, os.path.join('..', 'srcs'))

# %%
import utils.imagens_files as imfi
import numpy as np
import matplotlib.pyplot as plt

# %%
nome_file = os.path.join('..', 'imagens', 'Limes.jpg')

# %%
matriz = imfi.file_to_matriz(nome_file)

# %%
matriz
# Out:
# array([[[249, 255,  84],
#         [243, 255,  73],
#         [240, 255,  98],
#         ...,
#         [160, 194,  12],
#         [149, 173,  23],
#         [182, 196,  85]],
#
#        [[255, 246, 237],
#         [251, 248, 205],
#         [248, 251, 194],
#         ...,
#         [156, 175,  70],
#         [169, 185,  87],
#         [173, 183,  94]],
#
#        [[255, 251, 255],
#         [255, 254, 249],
#         [254, 254, 244],
#         ...,
#         [176, 190, 102],
#         [213, 225, 143],
#         [194, 201, 124]],
#
#        ...,
#
#        [[153, 187,   4],
#         [148, 182,   0],
#         [147, 180,   1],
#         ...,
#         [  2,   2,   4],
#         [  4,   4,   6],
#         [  6,   6,   6]],
#
#        [[149, 181,   0],
#         [151, 182,   1],
#         [148, 181,   4],
#         ...,
#         [  4,   4,   4],
#         [  6,   6,   6],
#         [  8,   8,   6]],
#
#        [[151, 179,   0],
#         [151, 180,   0],
#         [151, 180,   2],
# ...

# %%
plt.imshow(matriz)

# %%
matriz.shape
# Out:
# (225, 339, 3)

# %%
linhas = matriz.shape[0]
colunas = matriz.shape[1]

# %%
matrix_gray = np.zeros((linhas, colunas))

# %%
for i in range(linhas):
    for j in range(colunas):
        r, g, b = matriz[i,j]
        matrix_gray[i,j] = int((r + g + b)/3)

# %%
matrix_gray
# Out:
# array([[196., 190., 197., ..., 122., 115., 154.],
#        [246., 234., 231., ..., 133., 147., 150.],
#        [253., 252., 250., ..., 156., 193., 173.],
#        ...,
#        [114., 110., 109., ...,   2.,   4.,   6.],
#        [110., 111., 111., ...,   4.,   6.,   7.],
#        [110., 110., 111., ...,   5.,   7.,   9.]])

# %%
plt.imshow(matrix_grey, cmap='gray')
